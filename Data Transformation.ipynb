# %%
from sklearn.preprocessing import MinMaxScaler

# %%
data = [[10], [20], [30], [40], [50]]

# %%
s = MinMaxScaler()
normalized_data = s.fit_transform(data)

# %%
print(normalized_data)
# Out:
# [[0.  ]
#  [0.25]
#  [0.5 ]
#  [0.75]
#  [1.  ]]
