# %%
import pandas as ps

# %%
df = [['Faiz',19,25000],
      ['Khanif',29,50000],
       ['Rahul',31,40000]]

data = ps.DataFrame(df,columns = ['Name','Age','Salary'])

# %%
data
# Out:
#      Name  Age  Salary
# 0    Faiz   19   25000
# 1  Khanif   29   50000
# 2   Rahul   31   40000

# %%
data['Joining Age']=[19,21,22]

# %%
data
# Out:
#      Name  Age  Salary  Joining Age
# 0    Faiz   19   25000           19
# 1  Khanif   29   50000           21
# 2   Rahul   31   40000           22

# %%
data.drop(columns=['Joining Age'], inplace = False)
# Out:
#      Name  Age  Salary
# 0    Faiz   19   25000
# 1  Khanif   29   50000
# 2   Rahul   31   40000

# %%
data
# Out:
#      Name  Age  Salary  Joining Age
# 0    Faiz   19   25000           19
# 1  Khanif   29   50000           21
# 2   Rahul   31   40000           22

# %%
data['Emp_id'] = [100,101,102]
data=data.set_index('Emp_id')

# %%
data
# Out:
#           Name  Age  Salary  Joining Age
# Emp_id
# 100       Faiz   19   25000           19
# 101     Khanif   29   50000           21
# 102      Rahul   31   40000           22

# %%
data=data.reset_index('Emp_id')

# %%
data
# Out:
#    Emp_id    Name  Age  Salary  Joining Age
# 0     100    Faiz   19   25000           19
# 1     101  Khanif   29   50000           21
# 2     102   Rahul   31   40000           22

# %%
data = data.set_index(['Emp_id','Name'])

# %%
data
# Out:
#                Age  Salary  Joining Age
# Emp_id Name
# 100    Faiz     19   25000           19
# 101    Khanif   29   50000           21
# 102    Rahul    31   40000           22
