# %%
import pandas as ps
data = ps.read_csv(r'D:\Data Science\School_Attendance_by_Student_Group.csv')

# %%
data
# Out:
#      District code                   District name  \
# 0          00000CT                     Connecticut
# 1          00000CT                     Connecticut
# 2          00000CT                     Connecticut
# 3          00000CT                     Connecticut
# 4          00000CT                     Connecticut
# ...            ...                             ...
# 2014       9030022  The Woodstock Academy District
# 2015       9030022  The Woodstock Academy District
# 2016       9030022  The Woodstock Academy District
# 2017       9030022  The Woodstock Academy District
# 2018       9030022  The Woodstock Academy District
#
#                         Category                       Student group  \
# 0                            NaN                        All Students
# 1                   Homelessness  Students Experiencing Homelessness
# 2     Students With Disabilities          Students With Disabilities
# 3             Free/Reduced Lunch                  Free Meal Eligible
# ...

# %%
data['']
