# %%
import pandas as ps

# %%
df = {'Name':('Faiz','Khanif','Rahul'),
    'Age':(20,30,31),
      'Salary':(25000,30000,10000)}
data = ps.DataFrame(df)

# %%
data
# Out:
#      Name  Age  Salary
# 0    Faiz   20   25000
# 1  Khanif   30   30000
# 2   Rahul   31   10000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Salary  3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes

# %%
data.describe()
# Out:
#              Age        Salary
# count   3.000000      3.000000
# mean   27.000000  21666.666667
# std     6.082763  10408.329997
# min    20.000000  10000.000000
# 25%    25.000000  17500.000000
# 50%    30.000000  25000.000000
# 75%    30.500000  27500.000000
# max    31.000000  30000.000000

# %%
data['Joining_Age'] = [19,30,35]

# %%
data
# Out:
#      Name  Age  Salary  Joining_Age
# 0    Faiz   20   25000           19
# 1  Khanif   30   30000           30
# 2   Rahul   31   10000           35

# %%
data['Emp_id'] = [100,101,102]
data
# Out:
#      Name  Age  Salary  Joining_Age  Emp_id
# 0    Faiz   20   25000           19     100
# 1  Khanif   30   30000           30     101
# 2   Rahul   31   10000           35     102

# %%
data = data.set_index('Emp_id')

# %%
data
# Out:
#           Name  Age  Salary  Joining_Age
# Emp_id
# 100       Faiz   20   25000           19
# 101     Khanif   30   30000           30
# 102      Rahul   31   10000           35

# %%
data=data.reset_index('Emp_id')

# %%
data.loc[0]
# Out:
# Emp_id           100
# Name            Faiz
# Age               20
# Salary         25000
# Joining_Age       19
# Name: 0, dtype: object

# %%
data
# Out:
#    Emp_id    Name  Age  Salary  Joining_Age
# 0     100    Faiz   20   25000           19
# 1     101  Khanif   30   30000           30
# 2     102   Rahul   31   10000           35

# %%
data.loc[:,'Age']
# Out:
# 0    20
# 1    30
# 2    31
# Name: Age, dtype: int64

# %%
data.loc[1,'Name']
# Out:
# 'Khanif'

# %%
data.loc[0:2,'Salary']
# Out:
# 0    25000
# 1    30000
# 2    10000
# Name: Salary, dtype: int64

# %%
data
# Out:
#    Emp_id    Name  Age  Salary  Joining_Age
# 0     100    Faiz   20   25000           19
# 1     101  Khanif   30   30000           30
# 2     102   Rahul   31   10000           35

# %%
data.iloc[2]
# Out:
# Emp_id           102
# Name           Rahul
# Age               31
# Salary         10000
# Joining_Age       35
# Name: 2, dtype: object

# %%
data.iloc[:,0]
# Out:
# 0    100
# 1    101
# 2    102
# Name: Emp_id, dtype: int64

# %%
data.iloc[1:2,1:2]
# Out:
#      Name
# 1  Khanif
