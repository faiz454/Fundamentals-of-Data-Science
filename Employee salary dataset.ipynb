# %%
import pandas as ps
data = ps.read_csv(r'D:\Data Science\employee salary dataset.csv', index_col='EmployeeID')

# %%
data
# Out:
#                    Name  Department  Experience_Years Education_Level  Age  \
# EmployeeID
# 1            Employee_1   Marketing                15          Master   53
# 2            Employee_2  Operations                 7        Bachelor   25
# 3            Employee_3          IT                12     High School   51
# 4            Employee_4  Operations                 8             PhD   44
# 5            Employee_5  Operations                15          Master   36
# 6            Employee_6     Finance                 3     High School   50
# 7            Employee_7          IT                14             PhD   57
# 8            Employee_8          IT                17             PhD   34
# 9            Employee_9          IT                 4        Bachelor   53
# 10          Employee_10  Operations                18     High School   28
# 11          Employee_11   Marketing                 8             PhD   43
# ...

# %%
data.head()
# Out:
#                   Name  Department  Experience_Years Education_Level  Age  \
# EmployeeID
# 1           Employee_1   Marketing                15          Master   53
# 2           Employee_2  Operations                 7        Bachelor   25
# 3           Employee_3          IT                12     High School   51
# 4           Employee_4  Operations                 8             PhD   44
# 5           Employee_5  Operations                15          Master   36
#
#             Gender       City  Monthly_Salary
# EmployeeID
# 1           Female      Delhi          111416
# 2           Female  Bangalore           95271
# 3           Female  Hyderabad           69064
# 4             Male      Delhi           95091
# 5           Female      Delhi          132450

# %%
data.describe()
# Out:
#        EmployeeID  Experience_Years        Age  Monthly_Salary
# count    50.00000         50.000000  50.000000         50.0000
# mean     25.50000          9.900000  39.760000      82288.8000
# std      14.57738          5.349995  11.539745      33521.4379
# min       1.00000          1.000000  22.000000      28420.0000
# 25%      13.25000          5.250000  28.250000      59424.0000
# 50%      25.50000         10.000000  43.500000      73890.5000
# 75%      37.75000         14.750000  49.000000     107219.0000
# max      50.00000         19.000000  57.000000     149123.0000

# %%
data['Expense']=data['Monthly_Salary']*0.5

# %%
data
# Out:
#     EmployeeID         Name  Department  Experience_Years Education_Level  \
# 0            1   Employee_1   Marketing                15          Master
# 1            2   Employee_2  Operations                 7        Bachelor
# 2            3   Employee_3          IT                12     High School
# 3            4   Employee_4  Operations                 8             PhD
# 4            5   Employee_5  Operations                15          Master
# 5            6   Employee_6     Finance                 3     High School
# 6            7   Employee_7          IT                14             PhD
# 7            8   Employee_8          IT                17             PhD
# 8            9   Employee_9          IT                 4        Bachelor
# 9           10  Employee_10  Operations                18     High School
# 10          11  Employee_11   Marketing                 8             PhD
# 11          12  Employee_12          IT                 4          Master
# ...

# %%
data['Entry_Age'] = data['Age'] - data['Experience_Years']

# %%
data
# Out:
#     EmployeeID         Name  Department  Experience_Years Education_Level  \
# 0            1   Employee_1   Marketing                15          Master
# 1            2   Employee_2  Operations                 7        Bachelor
# 2            3   Employee_3          IT                12     High School
# 3            4   Employee_4  Operations                 8             PhD
# 4            5   Employee_5  Operations                15          Master
# 5            6   Employee_6     Finance                 3     High School
# 6            7   Employee_7          IT                14             PhD
# 7            8   Employee_8          IT                17             PhD
# 8            9   Employee_9          IT                 4        Bachelor
# 9           10  Employee_10  Operations                18     High School
# 10          11  Employee_11   Marketing                 8             PhD
# 11          12  Employee_12          IT                 4          Master
# ...

# %%
data['Name']
# Out:
# 0      Employee_1
# 1      Employee_2
# 2      Employee_3
# 3      Employee_4
# 4      Employee_5
# 5      Employee_6
# 6      Employee_7
# 7      Employee_8
# 8      Employee_9
# 9     Employee_10
# 10    Employee_11
# 11    Employee_12
# 12    Employee_13
# 13    Employee_14
# 14    Employee_15
# 15    Employee_16
# 16    Employee_17
# 17    Employee_18
# 18    Employee_19
# 19    Employee_20
# 20    Employee_21
# 21    Employee_22
# 22    Employee_23
# 23    Employee_24
# 24    Employee_25
# 25    Employee_26
# 26    Employee_27
# 27    Employee_28
# 28    Employee_29
# 29    Employee_30
# 30    Employee_31
# 31    Employee_32
# 32    Employee_33
# 33    Employee_34
# 34    Employee_35
# 35    Employee_36
# 36    Employee_37
# 37    Employee_38
# 38    Employee_39
# 39    Employee_40
# 40    Employee_41
# 41    Employee_42
# 42    Employee_43
# 43    Employee_44
# 44    Employee_45
# 45    Employee_46
# 46    Employee_47
# 47    Employee_48
# 48    Employee_49
# 49    Employee_50
# ...

# %%
columns=['Name','Age']
data[columns]
# Out:
#            Name  Age
# 0    Employee_1   53
# 1    Employee_2   25
# 2    Employee_3   51
# 3    Employee_4   44
# 4    Employee_5   36
# 5    Employee_6   50
# 6    Employee_7   57
# 7    Employee_8   34
# 8    Employee_9   53
# 9   Employee_10   28
# 10  Employee_11   43
# 11  Employee_12   49
# 12  Employee_13   23
# 13  Employee_14   27
# 14  Employee_15   49
# 15  Employee_16   49
# 16  Employee_17   41
# 17  Employee_18   51
# 18  Employee_19   32
# 19  Employee_20   49
# 20  Employee_21   46
# 21  Employee_22   54
# 22  Employee_23   22
# 23  Employee_24   48
# 24  Employee_25   34
# 25  Employee_26   24
# 26  Employee_27   27
# 27  Employee_28   29
# 28  Employee_29   48
# 29  Employee_30   30
# 30  Employee_31   54
# 31  Employee_32   45
# 32  Employee_33   36
# 33  Employee_34   53
# 34  Employee_35   53
# 35  Employee_36   45
# 36  Employee_37   33
# 37  Employee_38   23
# 38  Employee_39   24
# 39  Employee_40   38
# 40  Employee_41   23
# 41  Employee_42   23
# ...

# %%
col = ['Name','Department']
data[col]
# Out:
#            Name  Department
# 0    Employee_1   Marketing
# 1    Employee_2  Operations
# 2    Employee_3          IT
# 3    Employee_4  Operations
# 4    Employee_5  Operations
# 5    Employee_6     Finance
# 6    Employee_7          IT
# 7    Employee_8          IT
# 8    Employee_9          IT
# 9   Employee_10  Operations
# 10  Employee_11   Marketing
# 11  Employee_12          IT
# 12  Employee_13  Operations
# 13  Employee_14     Finance
# 14  Employee_15   Marketing
# 15  Employee_16     Finance
# 16  Employee_17   Marketing
# 17  Employee_18  Operations
# 18  Employee_19          HR
# 19  Employee_20   Marketing
# 20  Employee_21     Finance
# 21  Employee_22  Operations
# 22  Employee_23   Marketing
# 23  Employee_24          HR
# 24  Employee_25          HR
# 25  Employee_26          IT
# 26  Employee_27          IT
# 27  Employee_28     Finance
# 28  Employee_29   Marketing
# 29  Employee_30   Marketing
# 30  Employee_31          IT
# 31  Employee_32   Marketing
# ...
